# %% [markdown]
# <h1> Day 18 - Class </h1>
#
# ## Hypothesis Testing
#
# Inferential statistics allows you to make predictions (“inferences”) from that data. With inferential statistics, you take data from samples and make generalizations about a population. For example, you might stand in a mall and ask a sample of 100 people if they like shopping at Sears. You could make a bar chart of yes or no answers (that would be descriptive statistics) or you could use your research (and inferential statistics) to reason that around 75-80% of the population (all shoppers in all malls) like shopping at Sears.
#
# There are two main areas of inferential statistics:
#
# - Estimating parameters. This means taking a statistic from your sample data (for example the sample mean) and using it to say something about a population parameter (i.e. the population mean).
# - Hypothesis tests. This is where you can use sample data to answer research questions. For example, you might be interested in knowing if a new cancer drug is effective. Or if breakfast helps children perform better in schools.
#
# ### Definitions
#
#
# <b>Hypothesis</b> - A premise or claim that we want to test
#
# <b>Null hypothesis</b> - Ho - Currently accepted
#
# <b>Alternative hypothesis</b> - Ha - Involves the claim to be tested
#
# Null hypothesis and alternative hypothesis are mathematically opposite
#
# The two outcomes of a hypothesis tests are,
#
# 1) Reject null hypothesis
#
# 2) Fail to reject null hypothesis
#
# ### Sample problem 1
# "It is believed that a candy machine makes chocolate bars that are on average 5g. A worker claims that the machine after maintanence no longer makes 5g bars."
#
# Null hypothesis - Candy machine makes chocolate bars averaging
#
# Alternative hypothesis - After maintanence, candy machine no longer makes 5g bars
#
# Ho : μ = 5g
#
# Ha : μ != 5g
#
# How do you decide ?
#
# Test Statistics - Is calculated from sample data and used to decide whether to reject or fail to reject
#
# How do we go about it ?
#
# We can take a sample i.e. say 50 bars , get average weight, and calculate test statistics. i.e. we will check if the sample results are statistically significant or not
#
# #### Level Of confidence (c)
#
# How confident are we in our decision
#
# #### Level of significance (α)
#
# Statistical significance refers to the claim that a result from data generated by testing or experimentation is not likely to occur randomly or by chance but is instead likely to be attributable to a specific cause.
#
# α = 1 - c
#
# let's say level of confidence is 95% , i.e.
#
# c = 0.95
#
# α = 1 - c
#
#   = 1 - 0.95
#
#   = 0.05
#
# ### Sample problem 2
# Test scores are normally distributed with mean of 24.2 and standard deviation of 4.2. What is the probability that a student scores greater than 31 ?
#
# Mean = 24.2
# std  = 4.2
#
# <img src='img/hypothesis-01.png' />
#
# Let's see how many standard deviations out from the mean is the point 31. In other words let's calculate z-score of 31
#
# Z = (x - mean) / (standard deviation)
#
# (31 - 24.2) / 4.2  = 1.62
#
# P (X > 31 ) i.e probability of a randomnly chosen students mark to be greater than 31 is the same as P (Z > 1.62)
#
# How to find Z score given the confidence level ?
#
# Lets' see how to find the Z-Score corresponding to 95% confidence level.
#
# First we find the area from the left ,
#
# Area_from_Left = (1 + Confidence Level) / 2 = (1 + .95) / 2 = 0.975
#
# <img src='img/hypothesis-03.png' />
#
# For finding the Z-score corresponding to 0.975 , we refer the ztable
#
# <img src='img/hypothesis-04.png' />
#
# we can see the z-score as 1.9 + .06 = 1.96
#
# Some of the common confidence level zscores
#
# <img src='img/hypothesis-02.png' />

# %% [markdown]
# ### Sample problem 3
# Consider the below problem statement,
#
# <img src='img/hypothesis-05.png'/>
#
# We will reject the null hypothesis with 95% confidence because the zscore 5.06 falls on the rejection zone

# %% [markdown]
# When the number of samples < 30 and when the population standard deviation is not given (sometimes only sample standard deviation will be provided), it's a good indication that we should use T test. Rest of the process will be similar.
#
# For Z-test, we start the area from the left, whereas for T-test we start the area from the right

# %% [markdown]
# ### Universe
# Mu is also called as the universe. Sample (S) is always a subset of universe
#
# A smaller p-value means that there is stronger evidence in favor of the alternative hypothesis.
#
# If we do the study between one sample and one population it is called as 1 sample study.
#
# If we do for 2 samples then it's 2 sample study.
#
# If we do for 3 or mor esamples then it's called ANOVA
#
# Analysis of variance / Analysis of proportions
#
# - Standard Deviation
#     - 1 sample
#         - Chi Square test
#     - 2 samples
#         - F-Test
#     - Greater than 2 samples
#         - ANOVA
#
# - Mean
#     - 1 sample
#         - Less than 30 samples
#             - t-test
#         - Greater than 30 samples
#             - z-test
#     - 2 samples
#         - Less than 30 samples
#             - t-test
#         - Greater than 30 samples
#             - z-test
#         - Greater than 2 samples
#             - ANOVA
#
#
# ### One tailed test
#
# A one-tailed test is a statistical test in which the critical area of a distribution is one-sided so that it is either greater than or less than a certain value, but not both. If the sample being tested falls into the one-sided critical area, the alternative hypothesis will be accepted instead of the null hypothesis.
#
# When the testing is set up to show that the sample mean would be higher or lower than the population mean, it is referred to as a one-tailed test. The one-tailed test gets its name from testing the area under one of the tails (sides) of a normal distribution, although the test can be used in other non-normal distributions as well.
#
# ### Two tail test
# In statistics, a two-tailed test is a method in which the critical area of a distribution is two-sided and tests whether a sample is greater than or less than a certain range of values. It is used in null-hypothesis testing and testing for statistical significance. If the sample being tested falls into either of the critical areas, the alternative hypothesis is accepted instead of the null hypothesis. The two-tailed test gets its name from testing the area under both tails of a normal distribution, although the test can be used in other non-normal distributions.
#
# ### Bootstrap sampler method
#
# ### ANOVA
# An ANOVA test is a way to find out if survey or experiment results are significant. In other words, they help you to figure out if you need to reject the null hypothesis or accept the alternate hypothesis.
#
# More on ANOVA you can refer class 24

# %% [markdown]
# ### What are F-statistics and the F-test?
# The F-statistic is simply a ratio of two variances. Variances are a measure of dispersion, or how far the data are scattered from the mean. Larger values represent greater dispersion.

# %% [markdown]
# ## Reference
#
# http://web.stanford.edu/~rjohari/teaching/notes/226_lecture14_inference.pdf
#
# http://web.stanford.edu/group/poldracklab/statsthinking21/hypothesis-testing.html
#
# https://www.youtube.com/channel/UCEWpbFLzoYGPfuWUMFPSaoA/search?query=hypothesis
#
# https://blog.minitab.com/blog/adventures-in-statistics-2/understanding-analysis-of-variance-anova-and-the-f-test
