# %%
### "D:\sanooj\datascience\data\automobile-dataset\Automobile_data.csv"
### https://www.kaggle.com/toramky/automobile-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\sanooj\datascience\data\automobile-dataset\Automobile_data.csv')
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
class_vars = [] ## Can be a discrete variable OR nominal/ordinal .. let's name it class_vars
for i in df.columns:
    if df[i].nunique() < 8:
        class_vars.append(i)
print(class_vars)
# Out:
# ['symboling', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders']

# %%
## Let's imagine the problem in hand to be predicting/understanding price patterns
## Draw the distribution of price first (study of single continous variable)
## Draw the graph of price v/s make (study of continous variable v/s class variable)
## Draw the graphs of price v/s city mileage , high way mileage, length , width, height

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.distplot(df['price'])
plt.subplot(2,2,2)
sns.distplot(df['price'],kde=False)
plt.subplot(2,2,3)
sns.boxplot(df['price'])

# %%
plt.figure(figsize=(20,30))
plt.subplot(7,1,1)
sns.barplot(df['make'],df['price'])
plt.subplot(7,1,2)
sns.barplot(df['body-style'],df['price'])
plt.subplot(7,1,3)
sns.barplot(df['fuel-type'],df['price'])
plt.subplot(7,1,4)
sns.barplot(df['aspiration'],df['price'])
plt.subplot(7,1,5)
sns.boxplot(df['num-of-doors'],df['price'])
plt.subplot(7,1,6)
sns.boxplot(df['drive-wheels'],df['price'])

# %%
plt.figure(figsize=(15,15))
plt.subplot(5,2,1)
plt.scatter(df['city-mpg'],df['price'])
plt.xlabel('city-mpg')
plt.ylabel('price')
plt.subplot(5,2,2)
plt.scatter(df['highway-mpg'],df['price']) ## For 2 continous variables
plt.xlabel('highway-mpg')
plt.ylabel('price')
plt.subplot(5,2,3)
plt.scatter(df['length'],df['price']) ## For 2 continous variables
plt.xlabel('length')
plt.ylabel('price')
plt.subplot(5,2,4)
plt.scatter(df['width'],df['price']) ## For 2 continous variables
plt.xlabel('width')
plt.ylabel('price')
plt.subplot(5,2,5)
plt.scatter(df['height'],df['price']) ## For 2 continous variables
plt.xlabel('height')
plt.ylabel('price')
plt.subplot(5,2,6)
plt.scatter(df['wheel-base'],df['price']) ## For 2 continous variables
plt.xlabel('wheel-base')
plt.ylabel('price')
plt.subplot(5,2,7)
plt.scatter(df['stroke'],df['price']) ## For 2 continous variables
plt.xlabel('stroke')
plt.ylabel('price')
plt.subplot(5,2,8)
plt.scatter(df['horsepower'],df['price']) ## For 2 continous variables
plt.xlabel('horsepower')
plt.ylabel('price')
#plt.xticks(rotation=45)
plt.subplot(5,2,9)
plt.scatter(df['engine-size'],df['price']) ## For 2 continous variables
plt.xlabel('engine-size')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
## Questions
## How does the price vary based on drive-wheel ?
## How does the price vary based on body-type ?
## How does the price vary based on width,height,length ?
## How is mileage and price related ?

## Observations
## For drive-wheel RWD price is higher
## For fuel-type diesel price is higher
## For body type hardtop and convertible price is higher
## Higher the engine-size higher the price
## For higher priced cars, less mileage on city and highway
## As the length and width of the car increases price increases
## No relationship between height, wheel base, stroke, horsepower

## Positive correlation
## engine-size, length, width

## Negative correlation
## City, Highway mileage

## No Correlation
## Height, wheel base, stroke, horsepower

## Feedback from Bharat - Write the observations findings against each chart so that it speaks a story
