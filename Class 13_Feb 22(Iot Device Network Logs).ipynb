# %% [markdown]
# <h1>IOT Device Network Logs</h1>
#
# <pre>Preprocessed dataset for network based intrusion detection system in Iot Devices.
# Ultrasonic Sensor with Arduino and NodeMCU used to monitor the network and collect the network logs.
# NodeMCU with ESP8266 wifi module was used to send data to the server via wifi.
#
# This dataset is preprocessed according to the network based intrusion detection system in Iot devices.
# 0 - normal
# 1 - wrong setup
# 2 - ddos
# 3 - Data type probing
# 4 - scan attack
# 5 - man in the middle
# </pre>
#
# Kaggle URL <a href="https://www.kaggle.com/speedwall10/iot-device-network-logs"> here </a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\sanooj\datascience\data\iot-device-network-logs\Preprocessed_data.csv")
df
# Out:
#         frame.number       frame.time  frame.len          eth.src  \
# 0                  1  123722736684743         54   87971959760497
# 1                  2  123722736773147         62   87971959760497
# 2                  3  123722736824792         62  167275820076079
# 3                  4  123722736836228         54  167275820076079
# 4                  5  123722749684991         54   87971959760497
# ...              ...              ...        ...              ...
# 477421         87181  128413885087438         42  167275820076079
# 477422         69378  127166820599383         42  167275820076079
# 477423         81928  126800153119873         42  167275820076079
# 477424         37052  124902446969093         42  167275820076079
# 477425         78990  128113220512685         42  167275820076079
#
#                 eth.dst      ip.src      ip.dst  ip.proto  ip.len  tcp.len  \
# 0       167275820076079   192168035  1921680121       6.0    40.0      0.0
# ...

# %%
df['ip.proto'].value_counts()
# Out:
#  6.0     238580
# -1.0     159051
#  1.0      79020
#  17.0       774
#  2.0          1
# Name: ip.proto, dtype: int64

# %%
df['tcp.len'].value_counts()
# Out:
# 0.000000      304859
# 215.000000     54116
# 103.000000     39691
# 214.000000     13738
# 110.000000     12852
#                ...
# 215.112111         1
# 214.553233         1
# 215.286339         1
# 215.432818         1
# 214.304794         1
# Name: tcp.len, Length: 9371, dtype: int64

# %%
## Continous variables
## ----------------------
## frame.number
## frame.len
## eth.src
## eth.dst
## ip.src
## ip.dst
## ip.len
## tcp.len
## tcp.srcport
## tcp.dstport
## Value

## Discrete variables
## ------------------
## ip.proto
## normality

# %%
sns.heatmap(df.isna())

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,cmap='viridis')

# %%
df['frame.number'].value_counts()
# Out:
# 42      158306
# 98       79021
# 269      59522
# 54       46093
# 169      39697
#          ...
# 103          1
# 1107         1
# 596          1
# 469          1
# 282          1
# Name: frame.len, Length: 192, dtype: int64

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,20))
sns.distplot(df['frame.number'],kde=False)

# %%
sns.boxplot(df['tcp.len'])

# %%
plt.figure(figsize=(20,20))

sns.barplot(df['normality'],df['Value'])
