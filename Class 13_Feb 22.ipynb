# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ### Matplotlib
# ### Plotly
# ### Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = np.random.randint(0,10,10)
data
# Out:
# array([5, 2, 1, 3, 3, 1, 1, 1, 2, 2])

# %%
plt.plot(data)
# While studying 1 variable, then x axis will be the index and y axis will be the value
# This is called line graph

# %%
plt.plot(data,color='r',linewidth=10)

# %%
plt.plot(data,color='r',linewidth=10,alpha=0.4)

# %%
plt.plot(data,color='b',marker='o')

# %%
plt.plot(data,color='b',marker='2')

# %%
plt.plot(data,color='b',marker='o',markersize=5,markeredgecolor='b',markeredgewidth=20)

# %%
df = sns.load_dataset('titanic')

plt.plot(df['fare'][0:100])

# %%
plt.figure(figsize=(20,5))
plt.plot(df['fare'][0:100],marker='o')

# %%
plt.figure(figsize=(20,5))
plt.plot(df['fare'][0:100],marker='o')
plt.plot(df['fare'][100:200],marker='o')

# %%
plt.figure(figsize=(20,5))
plt.plot(df['fare'][0:100].values,marker='o')
plt.plot(df['fare'][100:200].values,marker='o')
## Can be used for comparing.. baselining .. e.g. plot the values.. make some change and 
## then compare to see the impact of the change with the new plot

# %%
## Kaggle Rossmann stores sale
## Check the sales when Promo was not given and compare it with the sales with Promo given

df = pd.read_csv(r"D:\sanooj\datascience\data\rossmann-store-sales\train.csv")
df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
df['Promo']
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 1017204    0
# 1017205    0
# 1017206    0
# 1017207    0
# 1017208    0
# Name: Promo, Length: 1017209, dtype: int64

# %%
df['Promo'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
plt.figure(figsize=(20,5))
df_with_promo = df[df['Promo'] == 1]
df_without_promo = df[df['Promo'] == 0]

plt.plot(df_with_promo['Sales'][0:100].values,marker='o',color='g')
plt.plot(df_without_promo['Sales'][0:100].values,marker='o',color='r')
plt.xlabel('days')
plt.ylabel('sales')
plt.title('Sales per day comparison with Promotion and without Promotion')
# Out:
# Text(0.5, 1.0, 'Sales per day comparison with Promotion and without Promotion')

# %%
plt.figure(figsize=(20,5))
df_with_promo = df[df['Promo'] == 1]
df_without_promo = df[df['Promo'] == 0]

plt.plot(df_with_promo['Sales'][0:100].values,marker='o',color='g')
plt.plot(df_without_promo['Sales'][0:100].values,marker='o',color='r')
plt.xlabel('days')
plt.ylabel('sales')
plt.title('Sales per day comparison with Promotion and without Promotion')
plt.xlim(0,60)
plt.ylim(0,10000) 
## xlim,ylim to focus on specific areas of the graph
# Out:
# (0, 10000)

# %% [markdown]
# ### Subplots (for better real estate and to show multiple graphs in one go)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)

# %%
## Plot is for single variable.. for two variables use scatter
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.scatter(df['Customers'],df['Customers'])
plt.subplot(2,2,2)
plt.scatter(df['Customers'],1/df['Customers'])
plt.subplot(2,2,3)
plt.scatter(df['Customers'],df['Customers']**3)
plt.subplot(2,2,4)
plt.scatter(df['Customers'],df['Customers']**4)

# %%
df_new = df[0:2000]
df_new.shape
# Out:
# (2000, 9)

# %%
counter = 1
num_cols = df_new.describe().columns
plt.figure(figsize=(20,20))
for i in num_cols:
    for j in num_cols:
        plt.subplot(7,7,counter)
        if i==j:
            plt.hist(df_new[i])
        else:
            plt.scatter(df_new[i],df_new[j])
        counter = counter+1

# %% [markdown]
# ### Seaborn plots

# %%
df = sns.load_dataset('titanic')

# %%
### Take a continous variable

# %%
sns.distplot(df['fare'])

# %%
sns.distplot(df['fare'],kde=False,color='r') ## Kernel Density Equation .. to avoid probability on y axis

# %%
sns.set_style("darkgrid")
sns.distplot(df['fare'],kde=False,color='r') ## Kernel Density Equation .. to avoid probability on y axis

# %%
plt.subplot(2,1,1)
sns.distplot(df['fare'],kde=False,color='r')
plt.subplot(2,1,2)
sns.distplot(df['fare'],kde=False,color='r')

# %%
sns.rugplot(df['fare'])

# %%
sns.jointplot(df['fare'],df['age']) ## For 2 continous variables

# %%
sns.jointplot(df['fare'],df['age'],kind='reg')## For 2 continous variables

# %%
sns.jointplot(df['fare'],df['age'],kind='hex')## For 2 continous variables

# %%
sns.jointplot(df['fare'],df['age'],kind='kde')

# %%
plt.hist(df['age'])
# Out:
# C:\Users\Rani\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Rani\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(df['age'])

# %%
sns.boxplot(df['survived'],df['age']) ## studying 1 class and 1 continous. 
# for survived 0 it shows box plot
# for survived 1 it shows the next box plot

# %%
sns.barplot(df['survived'],df['age']) # y axis shows the mean

# %%
sns.barplot(df['survived'],df['age'],estimator=np.std) # y axis shows the std

# %%
sns.barplot(df['survived'],df['age'],estimator=np.var) # y axis shows the std

# %%
sns.barplot(df['survived'],df['age'],estimator=np.mean) # y axis shows the mean

# %%
sns.violinplot(df['pclass'],df['age']) ## shows median, and maximum spread/maximum observation .. 
## for studying one class and one continuous variable

# %%
sns.swarmplot(df['pclass'],df['age'])
# Out:
# C:\Users\Rani\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\Rani\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.violinplot(df['pclass'],df['age'])
sns.swarmplot(df['pclass'],df['age'])
## Combination of violin and swarm together.. not much useful

# %%
sns.violinplot('survived','age',data=df,hue='pclass') ## deep dive into pclass

# %%
sns.violinplot('pclass','age',data=df,hue='survived') ## deep dive into pclass

# %%
df.isna()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
sns.heatmap(df.isna()) ## Can easily check the columns with null value

# %%
df.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(df.corr()) ## we can easily see the variables which are correlated

# %%
sns.heatmap(df.corr(),annot=True,cmap='viridis') ## annot=True will show the numbers..
plt.figure(figsize=(20,20))

# %% [markdown]
# ### All agricultural related dataset of India

# %%
agr_df = pd.read_csv(r"D:\sanooj\datascience\data\all-agriculture-related-datasets-for-india\csv")
agr_df
# Out:
#                     state        district      market              commodity  \
# 0     Andaman and Nicobar   South Andaman  Port Blair             Amaranthus
# 1     Andaman and Nicobar   South Andaman  Port Blair         Banana - Green
# 2     Andaman and Nicobar   South Andaman  Port Blair  Bhindi(Ladies Finger)
# 3     Andaman and Nicobar   South Andaman  Port Blair           Bitter gourd
# 4     Andaman and Nicobar   South Andaman  Port Blair           Black pepper
# ...                   ...             ...         ...                    ...
# 2233          West Bengal  Uttar Dinajpur    Islampur                 Potato
# 2234          West Bengal  Uttar Dinajpur    Islampur                   Rice
# 2235          West Bengal  Uttar Dinajpur     Raiganj                   Jute
# 2236          West Bengal  Uttar Dinajpur     Raiganj                   Rice
# 2237          West Bengal  Uttar Dinajpur     Raiganj                  Wheat
#
# ...

# %%
weather_df = pd.read_csv(r"D:\sanooj\datascience\data\all-agriculture-related-datasets-for-india\Min_Temp_IMD_2017.csv")
weather_df[weather_df['YEAR']==2019]
# Out:
#      YEAR    JAN    FEB    MAR   APR    MAY    JUN    JUL    AUG    SEP  \
# 116  2019  14.72  16.71  19.55  23.4  25.09  25.07  24.74  24.52  24.01
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 116  22.19  18.25  15.76   21.17    15.72    22.68    24.58    18.73

# %%
agr_df['arrival_date'].value_counts()
# Out:
# 04/03/2019    2238
# Name: arrival_date, dtype: int64

# %%
rice_df = agr_df[agr_df['commodity']=='Rice']
rice_df['variety'].value_counts()
# Out:
# Other                     14
# Fine                      11
# III                        9
# Common                     8
# Masuri                     2
# 1009 Kar                   2
# Coarse                     2
# H.Y.V.                     1
# Super Fine                 1
# Medium                     1
# Ratnachudi (718 5-749)     1
# Sanna Bhatta               1
# Name: variety, dtype: int64

# %%
agr_df['commodity'].value_counts()
# Out:
# Potato                 113
# Tomato                 103
# Brinjal                 99
# Paddy(Dhan)(Common)     99
# Onion                   99
#                       ...
# Rubber                   1
# Gingelly Oil             1
# Suvarna Gadde            1
# Amla(Nelli Kai)          1
# Karamani                 1
# Name: commodity, Length: 156, dtype: int64

# %%
continous_variables = agr_df.describe().columns
continous_variables
# Out:
# Index(['min_price', 'max_price', 'modal_price'], dtype='object')

# %%
plt.figure(figsize=(20,5))
#plt.plot(agr_df['min_price'][0:100].values,marker='o')
#plt.plot(agr_df['max_price'][0:100].values,marker='o')
plt.plot(fine_rice['max_price'].values,marker='o')

# %%
rice_df = agr_df[agr_df['commodity']=='Rice']
rice_varieties = rice_df['variety'].value_counts().index
rice_df
# Out:
#               state             district              market commodity  \
# 23            Assam               Cachar              Cachar      Rice
# 24            Assam               Cachar              Cachar      Rice
# 46            Assam               Dhubri            Gauripur      Rice
# 47            Assam               Dhubri            Gauripur      Rice
# 54            Assam               Jorhat              Jorhat      Rice
# 78            Assam             Sonitpur          Dhekiajuli      Rice
# 79            Assam             Sonitpur          Dhekiajuli      Rice
# 896         Manipur            Bishnupur           Bishenpur      Rice
# 905         Manipur              Chandel               Moreh      Rice
# 915         Manipur          Imphal East      Lamlong Bazaar      Rice
# 926         Manipur          Imphal West              Imphal      Rice
# 937         Manipur              Thoubal             Thoubal      Rice
# ...

# %%
plt.figure(figsize=(20,20))
plt.subplot(3,1,1)
sns.distplot(rice_df['min_price'],kde=False)
plt.subplot(3,1,2)
sns.distplot(rice_df['max_price'],kde=False)
plt.subplot(3,1,3)
sns.distplot(rice_df['modal_price'],kde=False)

# %%
counter = 1
for item in rice_varieties:
    print(item)
    plt.figure(figsize=(20,20))
    plt.subplot(12,1,counter)
    sns.distplot(rice_df[rice_df['variety']==item]['max_price'])
    counter = counter + 1
# Out:
# Other
# Fine
# III
# Common
# Masuri
# 1009 Kar
# Coarse
# H.Y.V.
# Super Fine
# Medium
# C:\Users\Rani\Anaconda3\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Rani\Anaconda3\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ratnachudi (718 5-749)
# Sanna Bhatta
