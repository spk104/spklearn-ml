# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread(r'D:\sanooj\datascience\notebooks\spklearn-ml\img\lion-01.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# http://cs231n.stanford.edu/
#
# We need square image to work with

# %%
img.shape

img=cv2.resize(img,(183,183))
plt.imshow(img)

# %%
img.shape
# Out:
# (183, 183, 3)

# %%
# Lets select 50 random 20 * 20 matrices
final_img_array = []
num_of_images = 50
max_size = 20
for index in range(num_of_images):
    feature = np.random.randint(0,20,(20,20))
    random = np.random.randint(0,163)
    random_width = random + max_size
    random_height = random + max_size
    subset_image = (img[np.ix_([random,random],[random_width,random_height])])
    cross_prod = np.multiply(feature, subset_image)
    #final_img_array.append((img[np.ix_([random,random],[random_width,random_height])]))
    
    plt.imshow(cross_prod)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-152d81bccd45> in <module>
#       9     random_height = random + max_size
#      10     subset_image = (img[np.ix_([random,random],[random_width,random_height])])
# ---> 11     cross_prod = np.multiply(feature, subset_image)
#      12     #final_img_array.append((img[np.ix_([random,random],[random_width,random_height])]))
#      13
#
# ValueError: operands could not be broadcast together with shapes (20,20) (2,2,3)

# %%
Convolute
Filters
Strides
Formula for output number (N-F)/Strides + 1
